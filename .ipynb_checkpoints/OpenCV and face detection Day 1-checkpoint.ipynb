# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = plt.imread('../imagify/sample_img2.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()
img.shape
# Out:
# (1365, 2048, 3)

# %%
# Load the XML File into a Cascade Classifier Model
detector = cv2.CascadeClassifier('../Imagify/haarcascade_frontalface_alt.xml')

# %%
# Detect the Faces
faces = detector.detectMultiScale(img,minSize=(50,50))

# %%
# Visualise output
for f in faces:
    x,y,w,h = f
    #Iterative over each face coordinates and drawing the rectangle
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)
    
plt.imshow(img)
plt.show()
